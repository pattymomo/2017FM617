# %%
import pandas as pd
dfs =pd.read_csv("http://www.nasdaq.com/screening/companies-by-industry.aspx?exchange=NASDAQ&render=download")

# %%
len(dfs)
# Out:
# 3270

# %%
nasdaq = dfs[0:]
nasdaq.ix[:,0:9]
# Out:
# C:\Users\Lenovo\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#      Symbol                                    Name LastSale     MarketCap  \
# 0       PIH  1347 Property Insurance Holdings, Inc.    7.225  4.323993e+07
# 1      TURN                180 Degree Capital Corp.    2.058  6.404817e+07
# 2      FLWS                 1-800 FLOWERS.COM, Inc.     9.55  6.171636e+08
# 3      FCCY           1st Constitution Bancorp (NJ)    18.35  1.481424e+08
# 4      SRCE                  1st Source Corporation    50.03  1.297585e+09
# 5      VNET                    21Vianet Group, Inc.     7.24  4.321689e+08
# 6      TWOU                                2U, Inc.    68.91  3.598642e+09
# ...
